# %% [raw]
# import pandas as pd
# from sklearn.model_selection import train_test_split
# from sklearn.model_selection import cross_val_score
# from sklearn.linear_model import LinearRegression as LR
# import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"D:\BaiduNetdiskDownload\美国King County房价预测训练赛\kc_train_all.csv",header=None)

# %%
data.columns= ['销售日期','销售价格','卧室数','浴室数','房屋面积','停车面积','楼层数','房屋评分','建筑面积','地下室面积','建筑年份','修复年份','纬度','经度']

# %%
data.head(200)
# Out:
#          销售日期     销售价格  卧室数   浴室数  房屋面积   停车面积  楼层数  房屋评分  建筑面积  地下室面积  建筑年份  \
# 0    20150302   545000    3  2.25  1670   6240  1.0     8  1240    430  1974
# 1    20150211   785000    4  2.50  3300  10514  2.0    10  3300      0  1984
# 2    20150107   765000    3  3.25  3190   5283  2.0     9  3190      0  2007
# 3    20141103   720000    5  2.50  2900   9525  2.0     9  2900      0  1989
# 4    20140603   449500    5  2.75  2040   7488  1.0     7  1200    840  1969
# ..        ...      ...  ...   ...   ...    ...  ...   ...   ...    ...   ...
# 195  20140529   231000    4  2.00  1530   6375  2.0     7  1530      0  1942
# 196  20140603  1099500    4  2.00  2580   6000  1.0     9  1300   1280  1950
# 197  20140627   275500    2  1.00   720  11400  1.0     6   720      0  1951
# 198  20140529   145000    3  1.00  1010   5490  1.0     6  1010      0  1954
# 199  20140924   154500    3  1.00   890   9465  1.0     6   890      0  1957
#
#      修复年份       纬度       经度
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   销售日期    10000 non-null  int64
#  1   销售价格    10000 non-null  int64
#  2   卧室数     10000 non-null  int64
#  3   浴室数     10000 non-null  float64
#  4   房屋面积    10000 non-null  int64
#  5   停车面积    10000 non-null  int64
#  6   楼层数     10000 non-null  float64
#  7   房屋评分    10000 non-null  int64
#  8   建筑面积    10000 non-null  int64
#  9   地下室面积   10000 non-null  int64
#  10  建筑年份    10000 non-null  int64
#  11  修复年份    10000 non-null  int64
#  12  纬度      10000 non-null  float64
#  13  经度      10000 non-null  float64
# dtypes: float64(4), int64(10)
# memory usage: 1.1 MB

# %%
from sklearn.preprocessing import MinMaxScaler
pd.DataFrame(data,columns=FEAT_CLOS)
# Out:
#           销售日期     销售价格  卧室数   浴室数  房屋面积    停车面积  楼层数  房屋评分  建筑面积  地下室面积  \
# 0     20150302   545000    3  2.25  1670    6240  1.0     8  1240    430
# 1     20150211   785000    4  2.50  3300   10514  2.0    10  3300      0
# 2     20150107   765000    3  3.25  3190    5283  2.0     9  3190      0
# 3     20141103   720000    5  2.50  2900    9525  2.0     9  2900      0
# 4     20140603   449500    5  2.75  2040    7488  1.0     7  1200    840
# ...        ...      ...  ...   ...   ...     ...  ...   ...   ...    ...
# 9995  20141121   302500    4  2.50  1990    5511  2.0     8  1990      0
# 9996  20141006   320000    4  2.50  2300    3825  2.0     7  2300      0
# 9997  20141014  1100000    4  3.50  4560   41636  2.0     9  4170    390
# 9998  20140620  1135000    6  4.25  6900  244716  2.0     9  4820   2080
# 9999  20150210   342888    2  1.00   790    5150  1.0     6   790      0
#
#       建筑年份  修复年份       纬度       经度
# 0     1974     0  47.6413 -122.113
# ...

# %%
scaler = MinMaxScaler()
scaler = scaler.fit(data)
result = scaler.transform(data)
result
# Out:
# array([[0.97755611, 0.06901615, 0.3       , ..., 0.        , 0.77955685,
#         0.3372093 ],
#        [0.9684788 , 0.10425844, 0.4       , ..., 0.        , 0.76500081,
#         0.40116279],
#        [0.95810474, 0.10132159, 0.3       , ..., 0.        , 0.63739285,
#         0.42940199],
#        ...,
#        [0.05107232, 0.15051395, 0.4       , ..., 0.        , 0.64628821,
#         0.33471761],
#        [0.01177057, 0.15565345, 0.6       , ..., 0.        , 0.95633188,
#         0.42109635],
#        [0.96837905, 0.03933744, 0.2       , ..., 0.        , 0.63642245,
#         0.2051495 ]])

# %%
x = pd.DataFrame(result,columns=FEAT_CLOS)
# x = pd.DataFrame(data,columns=FEAT_CLOS)
z = x.iloc[:,x.columns != "销售价格"]#筛选出其他列即影响因素
y = x.iloc[:,1]#筛选出价格列 也就是目标值

# %%
Xtrain,Xtest,Ytrain,Ytest = train_test_split(z,y,test_size = 0.3)

# %%
Xtrain
# Out:
#           销售日期  卧室数       浴室数      房屋面积      停车面积  楼层数  房屋评分      建筑面积  \
# 182   0.969975  0.3  0.322581  0.136842  0.000447  0.4   0.5  0.088548
# 5311  0.042095  0.2  0.290323  0.093684  0.001213  0.4   0.4  0.105077
# 7410  0.031721  0.4  0.709677  0.648421  0.131333  0.0   0.8  0.591499
# 7188  0.980050  0.5  0.225806  0.169474  0.005860  0.0   0.4  0.095632
# 4184  0.001397  0.4  0.451613  0.153684  0.003603  0.4   0.4  0.087367
# ...        ...  ...       ...       ...       ...  ...   ...       ...
# 9809  0.010873  0.2  0.129032  0.101053  0.005769  0.0   0.4  0.113341
# 2613  0.958903  0.3  0.193548  0.133684  0.001586  0.2   0.4  0.149941
# 6565  0.010274  0.3  0.451613  0.301053  0.003288  0.4   0.7  0.249115
# 4518  0.969875  0.4  0.387097  0.227368  0.002864  0.4   0.5  0.157025
# 1768  0.041895  0.4  0.290323  0.157895  0.004832  0.0   0.5  0.177096
#
#          地下室面积      建筑年份      修复年份        纬度        经度
# 182   0.114108  0.904348  0.000000  0.616367  0.109635
# ...

# %%
Xtest
# Out:
#           销售日期  卧室数       浴室数      房屋面积      停车面积  楼层数  房屋评分      建筑面积  \
# 6391  0.979751  0.4  0.225806  0.165263  0.002283  0.0   0.5  0.069658
# 407   0.997805  0.4  0.322581  0.191579  0.029563  0.0   0.5  0.214876
# 5804  0.032419  0.3  0.322581  0.316842  0.002754  0.4   0.5  0.225502
# 1136  0.000499  0.4  0.258065  0.191579  0.004836  0.0   0.5  0.096812
# 5736  0.959701  0.3  0.225806  0.181053  0.033693  0.0   0.4  0.128689
# ...        ...  ...       ...       ...       ...  ...   ...       ...
# 3229  0.968279  0.2  0.193548  0.120000  0.000267  0.4   0.5  0.095632
# 7331  0.968279  0.4  0.290323  0.283158  0.006006  0.4   0.6  0.317591
# 6956  0.957905  0.4  0.483871  0.263158  0.002176  0.4   0.6  0.218418
# 6968  0.988728  0.3  0.193548  0.089474  0.002125  0.2   0.5  0.100354
# 590   0.072020  0.4  0.290323  0.198947  0.004833  0.0   0.5  0.149941
#
#          地下室面积      建筑年份  修复年份        纬度        经度
# 6391  0.203320  0.104348   0.0  0.849749  0.123754
# ...

# %%
Ytrain
# Out:
# 182     0.052129
# 5311    0.042438
# 7410    0.209251
# 7188    0.057269
# 4184    0.025404
#           ...
# 9809    0.029648
# 2613    0.085609
# 6565    0.117474
# 4518    0.114537
# 1768    0.066079
# Name: 销售价格, Length: 7000, dtype: float64

# %%
Ytest
# Out:
# 6391    0.095441
# 407     0.055800
# 5804    0.143172
# 1136    0.105603
# 5736    0.079295
#           ...
# 3229    0.055066
# 7331    0.160059
# 6956    0.150514
# 6968    0.066814
# 590     0.068209
# Name: 销售价格, Length: 3000, dtype: float64

# %%
for i in [Xtrain,Xtest]:
    i.index = range(i.shape[0])
Xtrain.shape
# Out:
# (7000, 13)

# %%
reg = LinearRegression().fit(Xtrain,Ytrain)
yhat = reg.predict(Xtest)
yhat
reg.score(Xtest,Ytest)
# Out:
# 0.6553474140838615

# %%
reg.coef_
# Out:
# array([ 0.00495889, -0.0841364 ,  0.06511953,  0.14682215, -0.03007645,
#        -0.00452345,  0.16575673,  0.12507743,  0.06958602, -0.04964441,
#         0.00861045,  0.04753751, -0.02373714])

# %%
# [*zip(Xtrain.columns,reg.coef_)]

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2,include_bias=False)#添加多项式回归，增加拟合程度
Xtrain_poly = poly.fit_transform(Xtrain)#分别对训练集和测试集进行处理
Xtest_poly = poly.fit_transform(Xtest)#
# Xtrain_poly
# Xtest_poly
model = LinearRegression(normalize=True).fit(Xtrain_poly,Ytrain)
# model.fit(Xtrain_poly,Ytrain)
# Y_hast = model.predict(Xtest)
model.score(Xtest_poly,Ytest)
# Out:
# 0.7533072713026349

# %%
Y_hast = model.predict(Xtest_poly)
Y_hast

# %%
# Out:
# array([0.11386764, 0.05759036, 0.10574591, ..., 0.12162447, 0.07801223,
#        0.08279055])

# %%
from sklearn.metrics import mean_squared_error as MSE

# %%
MSE(yhat,Ytest)
# Out:
# 0.0009456555574222083

# %%
y.max()
# Out:
# 1.0

# %%
y.min()
# Out:
# 0.0

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(reg,z,y,cv=10,scoring="neg_mean_squared_error")
# Out:
# array([-0.00095966, -0.00089267, -0.00094954, -0.00103401, -0.00076838,
#        -0.00105697, -0.00114003, -0.00100003, -0.00138887, -0.00139755])

# %%
from sklearn.metrics import r2_score
r2_score(Ytest,yhat)

r2 = reg.score(Xtest,Ytest)
r2
# Out:
# 0.6553474140838615

# %%
cross_val_score(reg,z,y,cv=10,scoring="r2").mean()
# Out:
# 0.6471152499884172

# %%
import matplotlib.pyplot as plt
sorted(Ytest)
plt.plot(range(len(Ytest)),sorted(Ytest),c="black",label= "Data")
plt.plot(range(len(Y_hast)),sorted(Y_hast),c="red",label = "Predict")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
sorted(Ytest)
plt.plot(range(len(Ytest)),sorted(Ytest),c="black",label= "Data")
plt.plot(range(len(yhat)),sorted(yhat),c="red",label = "Predict")
plt.legend()
plt.show()

# %%
plt.plot(Ytest,yhat,'ro')
plt.plot(Ytest,Ytest,'b-')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(Ytest,Y_hast,'ro')
plt.plot(Ytest,Ytest,'b-')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
test = pd.read_csv(r"D:\BaiduNetdiskDownload\美国King County房价预测训练赛\kc_test.csv",header=None)

# %%
test = pd.DataFrame(test)
test
# Out:
#           销售日期  卧室数   浴室数  房屋面积   停车面积  楼层数  房屋评分  建筑面积  地下室面积  建筑年份  修复年份  \
# 0     20140502    2  1.00   880   6380  1.0     7   880      0  1938  1994
# 1     20150213    4  2.50  2880   8833  2.0     7  2880      0  2006     0
# 2     20141215    4  2.50  1980   5020  2.0     7  1980      0  2007     0
# 3     20140617    3  2.50  2830   6536  2.0     9  2830      0  1989     0
# 4     20150410    3  1.75  1900  13600  1.0     8  1900      0  1956     0
# ...        ...  ...   ...   ...    ...  ...   ...   ...    ...   ...   ...
# 2995  20150209    3  1.00  1200  10800  1.0     7  1200      0  1955     0
# 2996  20140916    4  1.75  2120   4000  1.5     8  1920    200  1929     0
# 2997  20140609    3  1.75  1240   8050  1.0     7  1240      0  1978     0
# 2998  20141030    3  2.50  2990  10711  1.0     9  1560   1430  1976  1991
# 2999  20140811    4  2.25  4220  24186  1.0     8  2600   1620  1984     0
#
#            纬度       经度
# 0     47.6924 -122.322
# ...

# %%
prediction = reg.predict(test)
print(prediction)
# Out:
# [ 99849.13207393 100346.67179907 100171.97988425 ...  99878.11807007
#  100214.26151345 100113.98645187]

# %%
result = pd.DataFrame(prediction)
result.head(200)
# Out:
#                  0
# 0     99849.132074
# 1    100346.671799
# 2    100171.979884
# 3    100355.853039
# 4     99940.511963
# ..             ...
# 195   99836.724166
# 196   99903.813157
# 197   99812.240291
# 198  100094.920002
# 199  100209.305384
#
# [200 rows x 1 columns]
