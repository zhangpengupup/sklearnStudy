# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import datetime as dt
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r'G:\traindata\RFMtest\tmp.xlsx')
df.head()
# Out:
#    payment             trdtime  id name
# 0      1.0 2019-12-25 01:07:14  13   吕游
# 1      NaN 2019-12-30 07:39:22  13   吕游
# 2     48.5 2020-06-22 11:51:51  46   卢芬
# 3     16.5 2020-06-27 02:32:09  46   卢芬
# 4    221.4 2020-06-30 12:15:34  46   卢芬

# %%
df['trdtime'] = pd.to_datetime(df['trdtime'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 394 entries, 0 to 393
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   payment  390 non-null    float64
#  1   trdtime  394 non-null    datetime64[ns]
#  2   id       394 non-null    int64
#  3   name     393 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 12.4+ KB

# %%
df['trdtime'].min()
# Out:
# Timestamp('2019-12-25 01:07:14')

# %%
R_today = dt.datetime(2020,8,27)

# %%
df['R_diff'] = (R_today-df['trdtime']).dt.days
df.head()
# Out:
#    payment             trdtime  id name  R_diff
# 0      1.0 2019-12-25 01:07:14  13   吕游     245
# 1      NaN 2019-12-30 07:39:22  13   吕游     240
# 2     48.5 2020-06-22 11:51:51  46   卢芬      65
# 3     16.5 2020-06-27 02:32:09  46   卢芬      60
# 4    221.4 2020-06-30 12:15:34  46   卢芬      57

# %%
R = df.groupby(by = ['id'])['R_diff']
R.head()
# Out:
# 0      245
# 1      240
# 2       65
# 3       60
# 4       57
#       ...
# 389      2
# 390      2
# 391      2
# 392      2
# 393      1
# Name: R_diff, Length: 373, dtype: int64

# %%
R = R.agg([('R_diff','min')])
R.head()
# Out:
#     R_diff
# id
# 13     240
# 46      38
# 48      13
# 51      18
# 82     239

# %%
F = df.groupby(by = ['id'])['id'].agg([('F_fre','count')])

# %%
M = df.groupby(by = ['id'])['payment'].agg([('M_sum',sum)])
RFM = R.join(F).join(M)
RFM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 262 entries, 13 to 514
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   R_diff  262 non-null    int64
#  1   F_fre   262 non-null    int64
#  2   M_sum   262 non-null    float64
# dtypes: float64(1), int64(2)
# memory usage: 18.2 KB

# %%
person = RFM.groupby(by = ['F_fre'])['F_fre'].agg([('F_fre','count')])
person.head(20)
# Out:
#        F_fre
# F_fre
# 1        198
# 2         40
# 3         11
# 4          3
# 5          2
# 6          3
# 7          3
# 8          1
# 14         1

# %%
RFM.describe()
# Out:
#            R_diff       F_fre       M_sum
# count  262.000000  262.000000  262.000000
# mean    29.015267    1.503817   72.784733
# std     24.710891    1.352585   97.306767
# min      1.000000    1.000000    1.000000
# 25%     18.000000    1.000000   24.350000
# 50%     26.000000    1.000000   42.950000
# 75%     34.000000    1.000000   79.400000
# max    240.000000   14.000000  964.700000

# %%
RFM["R_score"]=np.where(RFM.R_diff<=17,4,np.where(RFM.R_diff<=25,3,np.where(RFM.R_diff<=33,2,1)))
RFM["F_score"]=np.where(RFM.F_fre<=1,1,np.where(RFM.F_fre<=2,2,np.where(RFM.F_fre<=3,3,4)))
RFM["M_score"]=np.where(RFM.M_sum<=26.52,1,np.where(RFM.M_sum<=44,2,np.where(RFM.M_sum<=84,3,4)))
RFM.head()
# Out:
#     R_diff  F_fre  M_sum  R_score  F_score  M_score
# id
# 13     240      2    1.0        1        2        1
# 46      38      5  347.4        1        4        4
# 48      13      4  170.6        4        4        4
# 51      18      7  606.3        3        4        4
# 82     239      4    1.0        1        4        1

# %%
# RFM['RFM'] = 0.2*R1.astype(int)+0.3*F1.astype(int)+0.5*M1.astype(int)
# RFM.head()

# %%
RFM["RFM"] = RFM["R_score"]*0.4+RFM["F_score"]*0.1+RFM["M_score"]*0.5
RFM.head()
# Out:
#     R_diff  F_fre  M_sum  R_score  F_score  M_score  RFM
# id
# 13     240      2    1.0        1        2        1  1.1
# 46      38      5  347.4        1        4        4  2.8
# 48      13      4  170.6        4        4        4  4.0
# 51      18      7  606.3        3        4        4  3.6
# 82     239      4    1.0        1        4        1  1.3

# %%
bins = RFM.RFM.quantile(q = np.linspace(0,1,num = 9),interpolation = 'nearest')
labels = ['潜在客户','一般发展客户','一般保持客户','一般价值客户','重要挽留客户','重要发展客户','重要保持客户','高价值客户']
RFM['types'] = pd.cut(RFM.RFM,bins = bins,labels = labels,include_lowest = True)
RFM.head()
# Out:
#     R_diff  F_fre  M_sum  R_score  F_score  M_score  RFM   types
# id
# 13     240      2    1.0        1        2        1  1.1    潜在客户
# 46      38      5  347.4        1        4        4  2.8  重要发展客户
# 48      13      4  170.6        4        4        4  4.0   高价值客户
# 51      18      7  606.3        3        4        4  3.6   高价值客户
# 82     239      4    1.0        1        4        1  1.3    潜在客户

# %%
df1 = RFM.reset_index()
df1
df1.to_excel("testYD11.xlsx")

# %%
Money = df1.groupby(by = ['types'])['M_sum'].agg([('money_diff',sum)]).reset_index()
Money.head(9)
# Out:
#     types  money_diff
# 0    潜在客户       659.7
# 1  一般发展客户       954.9
# 2  一般保持客户      1709.9
# 3  一般价值客户       513.0
# 4  重要挽留客户      2892.5
# 5  重要发展客户      2405.0
# 6  重要保持客户      2951.1
# 7   高价值客户      6983.5

# %%
Person = df1.groupby(by = ['types'])['types'].agg([('num','count')]).reset_index()
Person.head(9)
# Out:
#     types  num
# 0    潜在客户   43
# 1  一般发展客户   38
# 2  一般保持客户   37
# 3  一般价值客户   20
# 4  重要挽留客户   26
# 5  重要发展客户   35
# 6  重要保持客户   30
# 7   高价值客户   33

# %%
plt.rcParams['font.sans-serif']=['SimHei'] #显示中文标签
plt.rcParams['axes.unicode_minus']=False   #如果表中有中文，则需要添加上面两行
plt.figure(figsize=(10,5))
plt.bar(data=Money,x = 'types',height = 'money_diff',color = 'rgb')
plt.show()

# %%
plt.rcParams['font.sans-serif']=['SimHei'] #显示中文标签
plt.rcParams['axes.unicode_minus']=False   #如果表中有中文，则需要添加上面两行
plt.figure(figsize=(10,5))
plt.bar(data=Person,x = 'types',height = 'num',color = 'rgb')
plt.show()

# %%
bins = RFM['R_diff'].quantile(q = np.linspace(0,1,6),interpolation = 'nearest')
bins[0] = 0
labels =  [5,4,3,2,1]
R1 = pd.cut(RFM['R_diff'],bins,labels = labels)

# bins = RFM['F_fre'].quantile(q = np.linspace(0,1,5),interpolation = 'nearest')
# bins[0] = 0
# labels = [1,2,6,8]
# F1 = pd.cut(RFM['F_fre'],bins,labels = labels)
bins = [1,2,5,8,30]
labels = np.arange(1,5)
F1 = pd.cut(RFM['F_fre'], bins=bins, labels=labels,include_lowest=True)


bins = RFM['M_sum'].quantile(q = np.linspace(0,1,6),interpolation = 'nearest')
bins[0] = 0
labels = [1,2,3,4,5]
M1 = pd.cut(RFM['M_sum'],bins,labels = labels)

RFM['R1'] = R1
RFM['F1'] = F1
RFM['M1'] = M1
RFM.head()
# Out:
#     R_diff  F_fre  M_sum R1 F1 M1
# id
# 13     240      2    1.0  1  1  1
# 46      38      5  347.4  2  2  5
# 48      13      4  170.6  5  2  5
# 51      18      7  606.3  4  3  5
# 82     239      4    1.0  1  2  1

# %%
print(np.arange(1,4))

# %%
RFM.describe()

# %%
rmd = r['R'].median()
fmd = r['F'].median()
mmd = r['M'].median()
rmd,fmd,mmd
# Out:
#            R_diff       F_fre       M_sum
# count  262.000000  262.000000  262.000000
# mean    29.015267    1.503817   72.784733
# std     24.710891    1.352585   97.306767
# min      1.000000    1.000000    1.000000
# 25%     18.000000    1.000000   24.350000
# 50%     26.000000    1.000000   42.950000
# 75%     34.000000    1.000000   79.400000
# max    240.000000   14.000000  964.700000

# %%
RFM['RFM'] = 0.3*R1.astype(float)+0.1*F1.astype(float)+0.5*M1.astype(float)
RFM.head()
# Out:
#     R_diff  F_fre  M_sum  R_score  F_score  M_score  RFM   types
# id
# 13     240      2    1.0        1        2        1  0.9    潜在客户
# 46      38      5  347.4        1        4        4  3.3  重要发展客户
# 48      13      4  170.6        4        4        4  4.2   高价值客户
# 51      18      7  606.3        3        4        4  4.0   高价值客户
# 82     239      4    1.0        1        4        1  1.0    潜在客户

# %%
bins = RFM['RFM'].quantile(q = [0,0.125,0.25,0.375,0.5,0.625,0.75,0.875,1],interpolation='nearest')
bins[0] =0
labels =  ['流失客户','一般维持客户','一般发展客户','潜力客户','重要挽留客户','重要保持客户','重要发展客户','重要价值客户']
RFM['types'] = pd.cut(RFM.RFM,bins,labels=labels)
RFM.head()
# Out:
#     R_diff  F_fre  M_sum  R_score  F_score  M_score  RFM   types
# id
# 13     240      2    1.0        1        2        1  0.9    流失客户
# 46      38      5  347.4        1        4        4  3.3  重要保持客户
# 48      13      4  170.6        4        4        4  4.2  重要价值客户
# 51      18      7  606.3        3        4        4  4.0  重要价值客户
# 82     239      4    1.0        1        4        1  1.0    流失客户

# %%
df2 = RFM.reset_index()
df2
df2.to_excel("testYD22.xlsx")

# %%
Money_ql = RFM.groupby(by = ['types'])['M_sum'].agg([('money_diff',sum)]).reset_index()
Money_ql.head(9)
# Out:
#     types  money_diff
# 0    流失客户       637.7
# 1  一般维持客户       656.6
# 2  一般发展客户      1469.8
# 3    潜力客户      1350.1
# 4  重要挽留客户      1218.4
# 5  重要保持客户      4050.1
# 6  重要发展客户      3044.6
# 7  重要价值客户      6642.3

# %%
person = RFM.groupby(by = ['types'])['types'].agg([('types','count')])
person.head(9)
# Out:
#         types
# types
# 流失客户       36
# 一般维持客户     36
# 一般发展客户     41
# 潜力客户       26
# 重要挽留客户     28
# 重要保持客户     37
# 重要发展客户     29
# 重要价值客户     29

# %%
df1 = RFM.reset_index()
df1
# Out:
#       id  R_diff  F_fre  M_sum  R_score  F_score  M_score  RFM   types
# 0     13     240      2    1.0        1        2        1  0.9    流失客户
# 1     46      38      5  347.4        1        4        4  3.3  重要保持客户
# 2     48      13      4  170.6        4        4        4  4.2  重要价值客户
# 3     51      18      7  606.3        3        4        4  4.0  重要价值客户
# 4     82     239      4    1.0        1        4        1  1.0    流失客户
# ..   ...     ...    ...    ...      ...      ...      ...  ...     ...
# 257  510       2      1  258.0        4        1        4  4.1  重要价值客户
# 258  511       2      1  294.0        4        1        4  4.1  重要价值客户
# 259  512       2      1   92.0        4        1        4  3.6  重要发展客户
# 260  513       2      1   57.9        4        1        3  3.6  重要发展客户
# 261  514       1      1   33.2        4        1        2  2.6  重要挽留客户
#
# [262 rows x 9 columns]

# %%
df1 = df1.pivot_table('id',index = 'types',aggfunc='count')
df1 = df1.rename(columns = {'id':'numbers'}).reset_index()
df1
# Out:
#     types  numbers
# 0    流失客户       36
# 1  一般维持客户       36
# 2  一般发展客户       41
# 3    潜力客户       26
# 4  重要挽留客户       28
# 5  重要保持客户       37
# 6  重要发展客户       29
# 7  重要价值客户       29

# %%
plt.rcParams['font.sans-serif']=['SimHei'] #显示中文标签
plt.rcParams['axes.unicode_minus']=False   #如果表中有中文，则需要添加上面两行
plt.figure(figsize=(10,5))
plt.bar(data=Money_ql,x = 'types',height = 'money_diff',color = 'rgb')
plt.show()

# %%
plt.rcParams['font.sans-serif']=['SimHei'] #显示中文标签
plt.rcParams['axes.unicode_minus']=False
plt.figure(figsize=(20,5))
plt.bar(data=df1,x = 'types',height = 'numbers',color = 'rgb')
plt.show()
