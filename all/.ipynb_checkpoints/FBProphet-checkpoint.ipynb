# %%
import numpy as np
import pandas as pd
from fbprophet  import Prophet

# %%
df = pd.read_excel(r"G:\traindata\yddata\forFBprophet.xlsx")
df['y'] = np.log(df['y'])
df.head()
# Out:
#           ds         y
# 0 2020-06-01  7.391415
# 1 2020-06-02  7.179460
# 2 2020-06-03  7.380318
# 3 2020-06-04  7.028113
# 4 2020-06-05  7.221690

# %%
m = Prophet()
m.fit(df)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=0)
future.tail()
# Out:
#            ds
# 61 2020-08-01
# 62 2020-08-02
# 63 2020-08-03
# 64 2020-08-04
# 65 2020-08-05

# %%
forecast = m.predict(future)
forecast.head()
# Out:
#           ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0 2020-06-01  7.162184    6.840926    7.529379     7.162184     7.162184
# 1 2020-06-02  7.160346    6.864029    7.575937     7.160346     7.160346
# 2 2020-06-03  7.158509    6.853519    7.508124     7.158509     7.158509
# 3 2020-06-04  7.156671    6.782463    7.504316     7.156671     7.156671
# 4 2020-06-05  7.154833    6.823656    7.554648     7.154833     7.154833
#
#    additive_terms  additive_terms_lower  additive_terms_upper    weekly  \
# 0        0.028620              0.028620              0.028620  0.028620
# 1        0.056133              0.056133              0.056133  0.056133
# 2        0.031916              0.031916              0.031916  0.031916
# 3       -0.005116             -0.005116             -0.005116 -0.005116
# 4        0.031859              0.031859              0.031859  0.031859
#
#    weekly_lower  weekly_upper  multiplicative_terms  \
# 0      0.028620      0.028620                   0.0
# 1      0.056133      0.056133                   0.0
# 2      0.031916      0.031916                   0.0
# 3     -0.005116     -0.005116                   0.0
# 4      0.031859      0.031859                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 0                         0.0                         0.0  7.190804
# 1                         0.0                         0.0  7.216479
# 2                         0.0                         0.0  7.190424
# 3                         0.0                         0.0  7.151555
# 4                         0.0                         0.0  7.186692

# %%
m.plot(forecast)

# %%
m.plot_components(forecast);

# %%
from sklearn.metrics import mean_absolute_error
import math

# %%
y = np.exp(df['y'] )

# %%
yhat = np.exp(forecast['yhat'])

# %%
mean_absolute_error(y,yhat)
# Out:
# 273.6010091719009

# %%
import numpy as np
def MAPE(true, pred):
    diff = np.abs(np.array(true) - np.array(pred))
    return np.mean(diff / true)
    pint(np.mean(diff / true))
MAPE(y,yhat)
# Out:
# 0.230274164257085

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(35, 15))#展示
ax = fig.add_subplot(111)
ax.plot(df.iloc[:,0],y-yhat,'r-')
ax.plot(df.iloc[:,0],y,'bo')
ax.plot(df.iloc[:,0],yhat,'g-')
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
